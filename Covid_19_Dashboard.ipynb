# %% [markdown]
# <a href="https://colab.research.google.com/github/abidshafee/Covid-19-Dashboard/blob/main/Covid_19_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dash
# !pip install -U dash-bootstrap-components

# %%
import pandas as pd
pd.set_option('max_rows',20)
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "browser"
import dash

# %%
from dash.dependencies import Input, Output
import dash_core_components as dcc
import dash_html_components as html
import dash_bootstrap_components as dbc

# %%
confirmed_case = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
death_case = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
# recovered = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'
recovered = 'https://raw.githubusercontent.com/abidshafee/Covid-19-Dashboard/main/time_series_covid19_recovered_global.csv'

df_confirmed = pd.read_csv(confirmed_case)
df_death = pd.read_csv(death_case) #error_bad_lines=False
df_recovered = pd.read_csv(recovered)

# %%
df_confirmed.head(3)
# Out:
#   Province/State Country/Region       Lat  ...  1/13/22  1/14/22  1/15/22
# 0            NaN    Afghanistan  33.93911  ...   158602   158639   158678
# 1            NaN        Albania  41.15330  ...   226598   228777   230940
# 2            NaN        Algeria  28.03390  ...   224383   224979   225484
#
# [3 rows x 729 columns]

# %%
df_death.head(3)
# Out:
#   Province/State Country/Region       Lat  ...  1/13/22  1/14/22  1/15/22
# 0            NaN    Afghanistan  33.93911  ...     7376     7376     7378
# 1            NaN        Albania  41.15330  ...     3255     3262     3265
# 2            NaN        Algeria  28.03390  ...     6383     6393     6404
#
# [3 rows x 729 columns]

# %%
df_recovered.head(10)
# Out:
#                  Province/State       Country/Region  ...  1/14/22  1/15/22
# 0                           NaN          Afghanistan  ...        0        0
# 1                           NaN              Albania  ...        0        0
# 2                           NaN              Algeria  ...        0        0
# 3                           NaN              Andorra  ...        0        0
# 4                           NaN               Angola  ...        0        0
# 5                           NaN  Antigua and Barbuda  ...        0        0
# 6                           NaN            Argentina  ...        0        0
# 7                           NaN              Armenia  ...        0        0
# 8  Australian Capital Territory            Australia  ...        0        0
# 9               New South Wales            Australia  ...        0        0
#
# [10 rows x 729 columns]

# %%
# get data in ceaned time series formate for country
def prcs_data(data, country="Bangladesh", win=3):
    confirmed = data
    confirmed_country = confirmed[confirmed['Country/Region']==country]
    final_data = confirmed_country.T[4:].sum(axis='columns').diff().rolling(window=win).mean()[30:]
    df = pd.DataFrame(final_data, columns=['Total'])
    return df

# %%
prcs_data(df_recovered)
# Out:
#          Total
# 2/21/20    0.0
# 2/22/20    0.0
# 2/23/20    0.0
# 2/24/20    0.0
# 2/25/20    0.0
# ...        ...
# 1/11/22    0.0
# 1/12/22    0.0
# 1/13/22    0.0
# 1/14/22    0.0
# 1/15/22    0.0
#
# [695 rows x 1 columns]

# %%
# get overall worldwide total for confirmed, recovered and death cases
def get_overall(df):
    return df.iloc[:,-1].sum()

overall_confirmed = get_overall(df_confirmed)
overall_death = get_overall(df_death)
overall_recovered = get_overall(df_recovered)

print("Overall Confirmed:", overall_confirmed)
print("Overall Death:", overall_death)
print("Overall Recovered:", overall_recovered)
# Out:
# Overall Confirmed: 326152828
# Overall Death: 5535426
# Overall Recovered: 0

# %%
df_recovered.sum(axis=1, skipna=True)

# %%
def country_total(df, country="Bangladesh"):
    return df[df['Country/Region']==country].iloc[:,-1].sum()

country = 'Bangladesh'
confirmed_country_total = country_total(df_confirmed, country)
dead_country_total = country_total(df_death,country)
recovered_country_total = country_total(df_recovered,country)
print(f'{country} Confirmed:', confirmed_country_total)
print(f'{country} Dead:', dead_country_total)
print(f'{country} Recovered:', recovered_country_total)
# Out:
# Bangladesh Confirmed: 1612489
# Bangladesh Dead: 28136
# Bangladesh Recovered: 0

# %%
def world_trend(data, country="Bangladesh", win=3):
    df = process_data(data, country, win)
    df.head(10)
    if win==1:
        yaxis_title = "Daily Cases"
    else:
        yaxis_title = "Daily Cases ({}-day MA)".format(win)
    fig = px.line(df, y='Total', x=df.index, title='Daily confirmed cases trend for {}'.format(country),height=600,color_discrete_sequence =['maroon'])
    fig.update_layout(title_x=0.5,plot_bgcolor='#F2DFCE',paper_bgcolor='#F2DFCE',xaxis_title="Date",yaxis_title=yaxis_title)
    return fig

# %%
world_trend(df_confirmed)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/plotly/express/_core.py in apply_default_cascade(args)
#     746         projection=dict(type=args["projection"]),
# --> 747     )
#     748
#
# /usr/local/lib/python3.7/dist-packages/plotly/io/_templates.py in __getitem__(self, item)
#      90                     template_dict = json.loads(template_str)
# ---> 91                     template = Template(template_dict, _validate=False)
#      92
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/layout/__init__.py in __init__(self, arg, data, layout, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    3481             The JSON encoding engine to use. One of:
# -> 3482               - "json" for an encoder based on the built-in Python json module
#    3483               - "orjson" for a fast encoder the requires the orjson package
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in _set_compound_prop(self, prop, val)
#    3835         """
# -> 3836         Return true of the input object is a list of dicts
#    3837         """
#
# /usr/local/lib/python3.7/dist-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2443         desc = (
# -> 2444             """\
#    2445     The '{plotly_name}' property is an instance of {class_str}
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/layout/template/__init__.py in __init__(self, arg, area, barpolar, bar, box, candlestick, carpet, choroplethmapbox, choropleth, cone, contourcarpet, contour, densitymapbox, funnelarea, funnel, heatmapgl, heatmap, histogram2dcontour, histogram2d, histogram, image, indicator, isosurface, mesh3d, ohlc, parcats, parcoords, pie, pointcloud, sankey, scatter3d, scattercarpet, scattergeo, scattergl, scattermapbox, scatterpolargl, scatterpolar, scatter, scatterternary, splom, streamtube, sunburst, surface, table, treemap, violin, volume, waterfall, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/_plotly_utils/importers.py in __getattr__(import_name)
#      40             "module {__name__!r} has no attribute {name!r}".format(
# ---> 41                 name=import_name, __name__=parent_name
#      42             )
#
# AttributeError: module 'plotly.validators.layout.template.data' has no attribute 'AreasValidator'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-c48a95e17898> in <module>()
# ----> 1 world_trend(df_confirmed)
#
# <ipython-input-116-a56da143d8d0> in world_trend(data, country, win)
#       6     else:
#       7         yaxis_title = "Daily Cases ({}-day MA)".format(win)
# ----> 8     fig = px.line(df, y='Total', x=df.index, title='Daily confirmed cases trend for {}'.format(country),height=600,color_discrete_sequence =['maroon'])
#       9     fig.update_layout(title_x=0.5,plot_bgcolor='#F2DFCE',paper_bgcolor='#F2DFCE',xaxis_title="Date",yaxis_title=yaxis_title)
#      10     return fig
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     212
#     213
# --> 214 def line(
#     215     data_frame=None,
#     216     x=None,
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1167                     and hover_data_is_dict
#    1168                     and args["hover_data"][str(argument)][1] is not None
# -> 1169                 ):
#    1170                     # hover_data has onboard data
#    1171                     # previously-checked to have no name-conflict with data_frame
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_core.py in apply_default_cascade(args)
#     748
#     749
# --> 750 def configure_animation_controls(args, constructor, fig):
#     751     def frame_args(duration):
#     752         return {
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/layout/__init__.py in __init__(self, arg, data, layout, **kwargs)
#
# ValueError: The first argument to the plotly.graph_objs.layout.Template
# constructor must be a dict or
# an instance of plotly.graph_objs.layout.Template
